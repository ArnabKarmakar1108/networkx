# %% [markdown]
# SRN1: PES1UG21CS164
# Team member 1:  Rameshwar DL
#
#
# SRN2: PES1UG21CS557
# Team member 2:  Shashank L Hosamani
#
# SRN3: PES1UG21CS571
# Team member 3:  Shreya Chakraborty
#
# SRN4: PES1UG21ME109
# Team member 4:  Samyam SP

# %% [markdown]
# Story file: The Adventures of Sherlock Holmes

# %% [markdown]
# Summary of the social graph reveals that there are 7 nodes and 8 edges, resulting in a graph density of 0.38. This density suggests that the graph is relatively sparse, indicating a moderate level of connectivity.
#
# Upon examining centrality measures, it becomes evident that Sherlock Holmes and Miss Mary Sutherland emerge as key influencers, exerting a notable impact on the overall structure of the graph. Their centrality highlights their significance within the network.

# %%
# !pip install community
# Out:
# Requirement already satisfied: community in c:\users\arnab\appdata\local\programs\python\python311\lib\site-packages (1.0.0b1)
# Requirement already satisfied: Flask in c:\users\arnab\appdata\local\programs\python\python311\lib\site-packages (from community) (3.0.0)
# Requirement already satisfied: requests in c:\users\arnab\appdata\local\programs\python\python311\lib\site-packages (from community) (2.31.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\arnab\appdata\local\programs\python\python311\lib\site-packages (from Flask->community) (3.0.0)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\arnab\appdata\local\programs\python\python311\lib\site-packages (from Flask->community) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\arnab\appdata\local\programs\python\python311\lib\site-packages (from Flask->community) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in c:\users\arnab\appdata\local\programs\python\python311\lib\site-packages (from Flask->community) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\arnab\appdata\local\programs\python\python311\lib\site-packages (from Flask->community) (1.6.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\arnab\appdata\local\programs\python\python311\lib\site-packages (from requests->community) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arnab\appdata\local\programs\python\python311\lib\site-packages (from requests->community) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arnab\appdata\local\programs\python\python311\lib\site-packages (from requests->community) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arnab\appdata\local\programs\python\python311\lib\site-packages (from requests->community) (2023.7.22)
# Requirement already satisfied: colorama in c:\users\arnab\appdata\roaming\python\python311\site-packages (from click>=8.1.3->Flask->community) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\arnab\appdata\local\programs\python\python311\lib\site-packages (from Jinja2>=3.1.2->Flask->community) (2.1.3)

# %%
import re
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from networkx.algorithms.community import k_clique_communities,girvan_newman
import community
# import community.community_louvain as community_louvain

# %%
with open('Hardy_Boys.txt',encoding="utf8") as text:
    book_text = text.read()

# %%
sections = book_text.split('* * *')
section_count = len(sections)
print(section_count)
# Out:
# 1

# %%
cleaned_sections = []

for section in sections:

    quotes = re.findall("“.*?”", section)
    for quote in quotes:
        section = section.replace(quote, " ")
    cleaned_sections.append(section)
print(cleaned_sections[0])
# Out:
# 1 Terror at 12,000 Feet
# I’m going to die.
#
# That’s what I thought when I pulled the cord of my parachute—and nothing happened.
#
# Definitely not cool.
#
# As I plummeted downward through the sky, it felt like I was floating. The earth below, on the other hand, was rushing up to greet me at a speed of 120 miles per hour.
#
# To make matters worse, it was my first solo jump.
#
# And probably my last.
#
# I tried not to panic. I looked over at   Maletta, the jumpmaster of Freedombird Skydiving School. The big bearded man was Freedom-falling about ten yards away from me. I waved to him like a maniac, pointing at my broken parachute cord.
#
# And guess what he did?
#
# He laughed.
#
# Seriously. Like some sort of cartoon villain on Saturday morning TV, he threw his oversized head back and laughed.
#
# Then it hit me.
#
# He knows who I am.
#
#   Frank shouted back. He held up a pair of tandem cords and clipped both of us to Wings’s backpack.
#
# I had to hand it to Frank. That kid is always prepared.
#
# Wings let out a sigh.   he shouted.
#
#   I said.
#
# Wings shrugged—and pulled.
#
# Whoomp!
#
# With a massive jolt, Frank and I were ripped away from our bear-sized enemy. We plummeted downward, then shot back up again, held by the tandem cords. The parachute opened above our heads, but it sagged with our weight. In seconds we were drifting toward the drop zone below.
#
# Problem was, we were drifting too fast.
#
#   Wings grunted.
#
# Frank and I ignored him as we scrambled up the cords and grabbed onto Wings’s legs.
#
#   the phony instructor yelled, trying to kick us off.   he added.
#
# I looked Frank in the eye. I knew what he was thinking: No way. We’re a team.
#
#   I said, shimmying my way up the guy’s body.
#
# Wings cursed. I ignored him and straddled his thick neck. Then I reached down to help my brother until we were both standing on Wing’s shoulders, holding the parachute lines for support.
#
#   Wings protested as we floated swiftly to the field below.
#
# I glanced at my brother and shrugged.   Frank said with a smile.
#
# The earth was only a couple hundred feet below us. Wings was freaking out.
#
#   I said.
#
#
#
#
#
# As it turned out, Wings did break his legs in the fall. Which made it impossible for him to run away when the police arrived. They’d been watching the whole thing from the ground—and had an ambulance waiting to pick up the pieces.
#
# I was just happy that none of the pieces had   written on them.
#
#   said Lieutenant Jones, smiling and shaking our hands.
#
#   Frank said, shaking his head.
#
#   I pointed out.
#
#   Frank added.
#
# I laughed.   I said, punching his arm.
#
# Frank returned the favor by pushing me off-balance.
#
#   Lieutenant Jones asked, opening the door of his squad car.
#
#   Frank explained.
#
# The police officer nodded and said good-bye.
#
# Five minutes later Frank and I reached the Freedombird Skydiving School. We were totally beat, not to mention a little bruised. But it felt good to complete another successful mission. Wings and his smuggling ring were safely behind bars. And the Hardy brothers were ready to relax and chill out with some friends.
#
# Unfortunately, Brian Conrad was the last   we wanted to see—and the first person to spot us approaching the Freedombird School.
#
#   I moaned to my brother.
#
#   Frank chipped in.
#
#   our least favorite classmate yelled from the parking lot.
#
# I glanced at Frank and rolled my eyes.
#
# Let me tell you about Brian Conrad. The guy is like that public access TV—nothing but bad news, twenty-four seven. If the yearbook committee was voting for Boy Most Likely to Need a Good Lawyer, he’d win, hands down.
#
# Of course, he hated Frank and me. In case you hadn’t noticed.
#
#   Brian taunted as we approached the school building.
#
# I growled under my breath.
#
#   my brother whispered. Then Frank looked Brian in the eye and said,
#
#   Brian shot back. He leaned against his SUV and shouted to his sister in the backseat.
#
# Belinda glared at her brother. She opened her mouth to say something—but she was interrupted by a high-pitched voice inside the school building.
#
#
#
# Brian Conrad burst out laughing.
#
# Frank and I turned toward the small brick building and exchanged puzzled glances. We didn’t know who it could be. The police had rounded up all of Wings’s men. So we headed for the door and carefully peeked inside.
#
#
#
# The sound came from a large gold cage in the corner.
#
# It was Wings’s pet parrot—the official mascot of the Freedombird Skydiving School.
#
#   I muttered.
#
# Frank entered the small reception room and walked to the cage.   he cooed to the red and green bird.
#
# The parrot tilted its head as if it understood.
#
#   Frank opened the cage door and the bird flew out.
#
# I ducked as it fluttered past my head.   I said.
#
# The parrot circled the room a few times—and landed on Frank’s head.
#
#   I said.
#
# Frank rolled his eyes upward. The bird squawked.
#
# And then Brian Conrad walked in.
#
#   the jerk sneered.   He pointed and laughed.
#
# Okay, stay cool, I told myself.
#
# If my brother and I could survive a parachute jump without pull cords, we could put up with Conrad’s obnoxious jokes.
#
# But come on. Did the bird have to join in, too?
#
#
#
#
# 2 Duck!
#   my brother Joe complained as we headed for the parking lot.
#
# I held the bird with one arm and opened the car door.   I said.   I gently placed the bird on the backseat of our Aunt Trudy’s old Volkswagen Beetle.
#
# Joe slid into the passenger seat and sighed.   he asked.
#
# The parrot flapped its wings.   it squawked.
#
# I laughed while Joe closed his eyes and groaned.   he said.
#
#   I reminded him again.
#
#   Joe explained.
#
#   I said.
#
# Aunt Trudy’s car engine died as soon as I tried to start it. And guess who we had to get a ride home from?
#
# Brian Conrad.
#
# I guess I spoke too soon.
#
# I had to wave the guy down before he pulled out of the parking lot. Needless to say, my brother was not thrilled.
#
#   Joe muttered under his breath.
#
# Brian’s SUV screeched to a stop next to Aunt Trudy’s dusty VW.   he teased us yet again.
#
#   Joe said defensively.
#
# I told my brother to chill out while we loaded our stuff into Brian’s SUV.
#
#   Joe whispered to me.
#
#   I warned, my face turning red.
#
# I guess I should explain. Brian’s sister, Belinda, is smart, funny, blond, beautiful—the whole package. And she smiles and touches my arm every chance she gets.
#
# Problem is, I get a little flustered around girls.
#
#   Belinda said, opening the rear door of the SUV. She flashed a smile that made me feel weak in the knees.
#
# Okay, maybe I get more than just a little flustered.
#
# Joe hopped into the front seat next to Brian. I knew the little creep grabbed shotgun just so he could watch me squirm next to Belinda.
#
# I tried to play it cool as I slid into the backseat—with a parrot on my shoulder.
#
# Real cool.
#
# We fastened our seatbelts and Brian peeled out of the parking lot like it was the Indy 500.   I pointed out.
#
#   he said, slowing down only slightly.
#
#   Belinda scolded her brother.   She placed a hand on my forearm.
#
#   I stuttered.
#
# What a dork.
#
#   I said, clearing my throat.
#
# Brian started clucking like a chicken, which caught the attention of the parrot on my shoulder. It raised its feathered head and squawked.
#
#   Belinda commented with a smile.
#
# I blushed.
#
#   she asked.
#
# I shrugged.
#
#   Brian said with a nasty laugh.
#
# The parrot ruffled his feathers and made a loud raspberry sound.
#
#   I said to my new feathered friend. The bird responded by poking my head with its beak.
#
# Belinda giggled.   she suggested.
#
# The parrot puffed up its chest.
#
#   Joe chimed in.
#
#   Brian added.
#
# The bird squawked back.
#
#   I said.
#
# The parrot flapped its wings with excitement.   it chirped.
#
#   said Belinda, slapping my knee.
#
#   Joe agreed.
#
#   I said, petting the parrot’s belly. I turned to Belinda and made a lame attempt at flirting.
#
# Real smooth.
#
#   I added, trying not to blush. I gave Belinda a cool sideways glance and nodded shrewdly.
#
# Saved!
#
# Well, until the parrot decided to poop on my shoulder.
#
#   I muttered.
#
# Everyone burst out laughing.
#
# But really, did they have to make jokes about it the entire ride home?
#
#   my brother said, mocking my own words.
#
# Belinda offered her sympathy—and a pack of tissues from her purse—but, boy, was I relieved when Brian pulled up in front of our house.
#
#   said Joe, hopping out and dashing to the porch of our old house. It was clear to everyone that Joe really hated thanking Brian for anything. He just wanted to make a quick escape.
#
# Which left me alone with Belinda in the backseat.
#
#   she said.
#
# Then she gave me a peck on the cheek.
#
# I’m sure my face turned redder than Playback’s tail feathers.   I stammered.
#
# Before I could embarrass myself any further, I ran up the porch stairs as fast as I could. I followed Joe into the house—and almost crashed right into him.
#
# The entire family was sitting in the dining room, staring at us. Mom, Dad, Aunt Trudy—and they all had strange, surprised looks on their faces.
#
#   Mom asked.
#
#   Playback responded.
#
# Mom chuckled.   she said.
#
#   I replied.
#
# Aunt Trudy was horrified.
#
#   I lied.
#
# I might have gotten away with it if Playback hadn’t chosen that exact moment to drop a little gift on my shoulder.
#
#   Aunt Trudy exclaimed.
#
#   I argued.
#
# Aunt Trudy stood up and started clearing plates off the table.   she said.
#
#   Joe and I said in unison.
#
# Mom stood up, came over to me, and petted the parrot.   she said.
#
#   I said, kissing her cheek.
#
# I glanced at Dad. I could tell he was concerned about the skydiving mission. But we’d have to talk about it later, when Mom and Aunt Trudy weren’t around.
#
#   Aunt Trudy questioned us.
#
# Oops.
#
# That was the reason Aunt Trudy had lent us her VW.   I said, wincing.
#
#   Joe confirmed.
#
#   she said, shaking her head.
#
# Joe and I glanced down at the bruises on our legs.
#
#   said my brother, thinking fast.
#
# We both gave our aunt a kiss and bounded up the stairs before she could ask any more questions. Playback clung to my shoulder and squawked.
#
# When we reached the second floor, Joe turned to me and said,
#
# I swatted the back of his head and followed him into my bedroom.   I asked.
#
# Joe walked to the window and turned around.
#
# I stopped listening, because something outside the window caught my eye.
#
# A big red brick sailed through the air. Right toward our window.
#
#   I yelled.
#
#
# 3 Extreme Danger
# Duck?
#
# I ducked.
#
# A split second later, something sailed past my head and crashed on the bedroom floor. I looked up to see what it was.
#
# A brick?
#
# I slowly raised myself to the window and peeked outside. The yard below was empty. Whoever threw the brick was gone.
#
#   I told Frank.
#
#   asked Frank.
#
#
#
#   Frank asked.
#
#   I said.
#
# Frank leaned over and picked it up. The brick was your basic red brick—nothing unusual. But it was tied to a small padded envelope.
#
#   I asked.
#
# Frank stood up.
#
# He opened the envelope and pulled out a wad of cash, a hotel reservation, a small laser pointer, and a CD.
#
#   said Frank, turning the CD around in his hand.
#
#   I asked.
#
# Frank looked me in the eye.   he said.
#
#   I replied, nodding.   I snatched the laser pointer out of Frank’s hands and snapped off the lights.
#
# Then, aiming toward the wall, I pressed the end of the pointer with my thumb. A tiny pinpoint of light danced across the room.
#
# Playback squawked.
#
# With a flutter of wings, the large bird flew off Frank’s shoulder and chased the pinpoint from one side of the room to the other. It was pretty hilarious watching Playback go. By swirling the laser, I could even make him fly in a perfect circle above our heads!
#
#   said Frank.
#
#   I insisted.
#
#
#
#   Fun wasn’t in my brother’s vocabulary. I aimed the laser above the TV set until Playback came to rest on top of it.
#
# The parrot touched the tip of his beak to the pinpoint of light and screeched so loud it made me jump.
#
#   said Frank.
#
# I released my thumb. The pinpoint of light disappeared instantly, but it left a small burn mark on the wall.
#
#   said Frank, snatching the pointer away from me and snapping on the lights.
#
#   I said, reaching for the game controls.
#
#
#
# I had to bite my lip to keep from laughing.
#
#   I said, taking the CD from Frank and loading the game player. We plopped down on the beanbag chairs in front of the monitor and prepared ourselves for our next mission.
#
# Bring it on.
#
# I pressed PLAY.
#
# The picture turned black. A low electronic hum grew louder and louder until it sounded like a chorus of spinning wheels. Suddenly the wheel sounds screeched to a halt, and two red slash marks crisscrossed the screen to form a giant X Then there was a sizzling noise—like the sound of a burning fuse—and a huge explosion. The giant X burst into a fireball of tiny cartoon flames.
#
#   I said.
#
#   Frank responded.
#
# The flames burned a bunch of holes in the screen, revealing a dozen little scenes—videostream clips of people skateboarding, bungee jumping, rock climbing, motocross racing, you name it.
#
#   a deep voice boomed over the soundtrack.
#
#   I said, slapping Frank’s knee.   On the screen a leather-jacketed motocrosser flipped backward on his bike and crashed headfirst on the ground.
#
#
#
#   said Frank.
#
#   the deep-voiced narrator continued.
#
#   I said.
#
#   Frank warned.
#
#
#
# I turned my attention back to the screen. The videostreamed sports footage was suddenly replaced with tourist shots of Philadelphia.
#
#   the voice went on.
#
# I looked at Frank.
#
#   he agreed.
#
# Then another voice came from the speakers. It sounded like it was making fun of the narrator.
#
#   I said, grabbing the controls and pressing the button.
#
#   said Frank.
#
# The tourist shots disappeared. A detailed map of Philadelphia filled the screen.
#
#   said the second voice.
#
# A yellow square flashed on the map, indicating the hotel’s location.
#
#
#
# This was going to be great!
#
# Frank didn’t seem as excited.   he muttered.
#
#   the voice spoke up.
#
# I glanced at Frank. He sighed.
#
#   the voice went on.
#
# The Beastie Boys blared from the speakers.
#
# The music was so loud it scared Playback off the TV He flapped his wings and flew into the air, then landed on Frank’s shoulder. He looked a little shaken. But after a moment or two he was grooving to the beat—and squawking the lyrics.
#
#
#
# Frank walked over to the computer, turned it on, and logged in.
#
#   I asked.
#
#   he replied.
#
#   I said.
#
#   he said, tapping his head with a finger.
#
#   I said.
#
#   he said, hunkering over the computer.
#
# While Frank launched his Web search, I went to ask Dad to drive us to the garage to pick up our motorcycles. He was sitting by himself at the dining room table.
#
#   he whispered, looking up from his newspaper.
#
#   I said, noticing the concerned look on his face. Then I turned around and headed back upstairs.
#
# Frank hadn’t moved since I’d left him.
#
#   I asked.
#
# Frank squinted at the screen.
#
# I leaned over his shoulder—the shoulder without the parrot—and studied the screen. In a tall, narrow window, there was a long scroll of postings. I started reading.
#
#   I said.
#
#   he said, reading out loud.
#
# I shrugged.
#
#   Frank admitted.
#
# I rolled my eyes.
#
# Frank sighed.   he said, logging off the computer.
#
#
#
# Frank smiled.
#
# I turned around and started filling my backpack with clothes and socks and underwear. Frank got up from the desk and walked to the video game player. He pressed EJECT and pulled out the disk.
#
# I stopped packing.   I asked.
#
# Frank paused.   he answered.
#
# I didn’t know what to say.
#
# But Playback did.
#
#
#
#
# 4 Warning Signs
# Call me paranoid. But I couldn’t shake the feeling that there was more to this mission than met the eye.
#
# Extreme danger.
#
# The phrase reminded me of a road sign warning—sort of like FALLING ROCKS or SLIPPERY WHEN WET.
#
# I really wanted to do a little more snooping around online—check out some other extreme sports Web sites—so I packed my laptop along with my clothes.
#
#
# I laughed.   I said.
#
#   Jenna said with a wink.
#
# Nice.
#
#   Jenna asked me.
#
#   I said.
#
#   said Jenna.
#
#   I said, even though I wasn’t thrilled about riding a hot-pink skateboard.
#
#   someone yelled across the lobby. I looked over to see a group of skateboarders in front of the elevators.
#
#   Jenna yelled back at them. She threw her board on the floor and hopped on.   she whispered.   Then she skated away.
#
# Excellent.
#
#   asked Frank, coming up behind me.
#
#   I bragged.
#
#
#
#
#
#
#
#
#
# My brother looked annoyed.   he said, lowering his voice.
#
#   I replied.
#
# Frank raised an eyebrow.   he admitted.
#
# We took the elevator up to our hotel room, unpacked our stuff—and suddenly realized we were starving.
#
#   said Frank.
#
#   I suggested.
#
# Frank agreed.
#
# We left our room and went downstairs, passing through the circus in the lobby and heading for an exit. When we got outside, we were surprised to see that the sidewalks were just as crowded as the hotel.
#
#   said Frank, staring at all the extreme athletes and fans passing by.
#
# I could tell he was trying to eavesdrop on their conversations—listening for anything suspicious. That was my brother. Always on the case.
#
# We walked a few blocks, just enjoying the sights, until we stumbled on a small skateboard store. The place was a little run-down but seemed to carry all the latest boards and equipment. A sign above the door said OLLIE’S SKATE SHOP.
#
#   said Frank.
#
# I was starving, but I didn’t feel like arguing with my brother. He was a man on a mission.
#
# A little bell jingled when we opened the door and stepped inside. The place was packed with merchandise, but not many customers. There were just a few teenaged boys trying on helmets, and two girls looking at T-shirts.
#
#   a deep gravelly voice shouted from behind the counter.
#
# Frank and I turned to see who was shouting. It was a middle-aged man with a bad sunburn, a walking cane, tattooed arms, and long blond hair tied in a ponytail. He looked kind of like an angry surfer.
#
# Lucky for us, he was pointing at the other boys in the store.   he barked.
#
#   one of the boys shot back.
#
# The ponytailed man fixed his cold blue eyes on the boys—then slowly reached under the counter.   he snarled.
#
# Nobody moved for a moment or two. Then the boys put down the helmets and walked out of the store.   one of them mumbled as the door closed with a jingle.
#
# Frank tapped my arm, then nodded at a handwritten sign next to the register. It said, AS AN AMERICAN CITIZEN, I FULLY EXERCISE MY RIGHT TO BEAR ARMS. SHOPLIFTERS: BEWARE.
#
# I glanced back at Frank. He raised his eyebrows and tilted his head toward a bulletin board.
#
# I turned and looked. The board was covered with photos of Ollie looking young and fit—and soaring through the air on a skateboard. There were newspaper clippings, too, with headlines like OLLIE PETERSON: NATIONAL SKATEBOARD CHAMP 1986 and OLLIE WINS AGAIN! I had to squint to read the small clipping on the bottom: SKATEBOARD LEGEND TAKES A FALL.
#
#   Ollie grunted, slamming his cane down on the counter.
#
# I tried to think fast.   I answered.
#
# Ollie growled and lowered his cane, then limped toward a large skateboard display.   he said.
#
# Why not buy one? That way I wouldn’t have to share Jenna’s tomorrow.
#
# It took only about three minutes for Ollie to convince me to buy a brand-new THX-720 with red flame detailing. And it matched my motorcycle!
#
# Frank, in the meantime, was studying the articles on the bulletin board—gathering information, as usual.
#
# As Ollie rang up my purchase, one of the girls walked up to the counter and said,
#
# Wrong question.
#
# Ollie almost threw a fit.   he snapped.
#
# SUSPECT PROFILE
#
# Name: Owen Peterson, aka
#
# Hometown: San Diego, CA
#
# Physical description: 40 years old, 5′11″, 170 pounds, shoulder-length blond hair, blue eyes, walks with limp, carries cane, dragon tattoos on forearms
#
# Occupation: Owner/operator of Ollie’s Skate Shop in downtown Philadelphia
#
# Background: Former professional skateborder (career ended after accidental injury in 1990)
#
# Suspicious behavior: Threatened customers, reached for (alleged) gun under store counter, talked about replacing skateboard bearings with nitroglycerin
#
# Suspected of: Attempted sabotage
#
# Possible motives: Revenge against Big Air Games (business dispute), personal resentment
#
# The girl blinked her eyes.   she asked.
#
#   he boomed.
#
# The girl shrugged and left the store with her friend.
#
# A few seconds later Ollie calmed down enough to take my money and complete my purchase.
#
# Frank strolled over to the counter.   he said to Ollie.
#
# Ollie rolled his eyes.   he sneered.
#
#   said Frank.
#
# Ollie laughed.   he growled.
#
#   said Frank, leaning over the counter.
#
# Ollie grabbed a skateboard off the display and flipped it over.   he said, giving it a spin.
#
# Frank and I nodded.
#
#   Ollie continued.
#
# Yes, we got the picture.
#
# And it wasn’t very pretty.
#
# Talk about killer wheels.
#
# I grabbed my new skateboard and nudged my brother.
#
# My brother agreed.   he said as we left the store.
#
# Yeah, I thought. It’s always nice to talk to a crazy washed-up skateboarder who wants to blow people up.
#
#
# 6 Attacked!
# Joe and I didn’t get to eat until ten o’clock at night. (My fault, because it was my idea to go inside Ollie’s Skate Shop.)
#
# And we didn’t get to sleep until one o’clock in the morning, (Joe’s fault, because it was his idea to call up Jenna Cho when we returned to the hotel.)
#
# Anyway, Jenna convinced my brother that we should skip the pregame events in the morning. The official opening ceremonies would be held the following day. She suggested we sleep in, grab a late breakfast, then meet her in the park with the other skaters.
#
# Sounded good to me. I was exhausted.
#
# After a full day of skydiving, motorcycle-riding, skateboard-shopping, a whole pizza at ten o’clock—and listening to Joe yammer on with his new girlfriend—who could blame me for being tired?
#
# Ah, sleep.
#
#   said Joe, hitting me with a pillow.
#
# I rubbed my eyes and looked at the clock radio.
#
# Nine forty-five?
#
# I think it was the first time in history that Joe woke up before I did.   I mumbled sleepily.
#
#   said Joe, tossing me a pair of shorts and a shirt.
#
# I crawled out of bed, hopped in the shower, and got dressed as quickly as I could. Joe insisted that we ride our cycles to the park.
#
#   he said, adding,
#
# About twenty minutes later, we arrived at FDR Park. Jenna Cho was waiting with her pink skateboard at the entrance.
#
#   She greeted us with a big smile and a thumbs-up.
#
#   Joe whispered to me. Then he flashed a smile at his new friend.
#
# Jenna swung her skateboard like a baseball bat.   she said, laughing.
#
#   I asked.
#
# Joe swatted my arm.   he explained to Jenna.
#
#   I added.
#
# After the introduction we found a spot to park our bikes and ordered three cheese steaks at a nearby stand.
#
#   I said, taking a bite.
#
# Jenna nodded.
#
# We strolled through the park, chomping on our cheese steaks, while Jenna showed us the sights.   she said.
#
#   Joe said, waving the new skateboard he’d bought at Ollie’s.
#
#   asked Jenna.
#
# I shrugged.
#
#   my brother teased.
#
# I decided to change the subject. Now was my chance to ask about the rumors of a possible attack.   I started off,
#
# Jenna thought about it, then said,
#
#   I asked.
#
#   she said.
#
# Definitely a motive for sabotaging your opponent, I thought.
#
# We were almost in the middle of the park. A few kids on skateboards and motocross bikes whizzed past us.   Jenna said, pointing past some trees.
#
# Suddenly a loud siren blasted right behind us.
#
#   Joe yelled.
#
# We jumped out of the way as a white EMT ambulance barreled past us with its lights flashing.
#
#   Jenna shouted.
#
#   I said, slapping my brother’s shoulder.
#
# The three of us dashed after the ambulance, pushing past dozens of gawking skaters and bikers. The siren stopped blaring. The vehicle pulled to a halt in front of a graffiti-covered ramp under the highway overpass. We rushed over to the center of the action.
#
# A muscular dark-haired boy lay on the concrete next to his skateboard.   he howled in pain.
#
#   Jenna whispered to Frank and me.
#
# Not anymore.
#
# A tall skinny paramedic applied bandages to the boy’s knees and shouted over his shoulder,
#
# A short stocky technician jumped out of the ambulance with a small case of supplies. I watched the two men do their job and I checked out the ID badges on their chests.
#
# The short guy was named Jack Horowitz, and the tall skinny guy was Carter Bean. Carter seemed to be the more experienced of the two. He filled a hypodermic needle and gave Gongado a shot of painkiller in about fifteen seconds flat.
#
#   a high-pitched voice cried out.
#
# A short frizzy-haired young woman pushed past us and rushed toward the stricken boy. Carter blocked her with his arm.   he said firmly.
#
# The girl backed off but kept talking.
#
# Gongado blinked his eyes. Obviously the painkillers were kicking in, but he was able to talk.
#
# The girl burst into tears.   she asked.
#
# Gongado shook his head.   Then he closed his eyes and passed out.
#
# A man with a camera stepped forward.   he shouted into the crowd.
#
# Nobody said anything.
#
#   Carter asked the man.
#
#   he told the paramedic.
#
#   Carter said calmly. He turned to help his coworker lift the boy onto a stretcher and into the ambulance.
#
# The reporter snapped away with his camera. Even after the ambulance drove off, he kept pursuing the story. But instead of taking pictures, he interviewed half the kids in the crowd.
#
# After a while, the reporter went away—and the scene returned to normal. The skateboarders practiced their kickies and heelies while the bikers hurtled over ramps. Jenna, Joe, and I found a spot under a nearby tree.
#
#   I asked Jenna.
#
#   she said,
#
#   I said.
#
#   said Jenna.
#
#   I asked.
#
# Jenna pointed across the park.   She poked my brother’s arm.
#
# Joe and Jenna ran off with their skateboards.
#
# And me? I decided to have a little talk with Eddie Mundy.
#
#   I said, approaching him during a break.
#
# Eddie sat down on his board and looked up at me suspiciously.   he asked. He was lean, lanky—and a little scary-looking, I had to admit.
#
#   I said, nodding at the other skateboarders.
#
# Eddie shrugged.   he grunted.
#
#   I said.
#
#   said Eddie, squinting his eyes.   He let out a little laugh.
#
#   I asked.
#
# Eddie didn’t answer. He just stared at me.
#
#   I lied.
#
#   said Eddie.
#
# He gave me a hard look. I figured I was pushing my luck, so I simply said thanks and good-bye. I walked around the skateboard park looking for Joe. I wanted to get him up to speed.
#
# SUSPECT PROFILE
#
# Name: Edward Mundy, aka
# Physical description: 18 years old, 6′1″, 180 pounds, brown hair, green eyes, wears red bandanna
# Hometown: Philadelphia, PA
# Occupation: Hardware store clerk, amateur skateboarder
# Background: Former title holder in regional skateboard contests, currently competing in Big Air Games
# Suspicious behavior: Laughed about Gongado Lopez’s attack and leg injuries, referred to Frank’s questioning as
# Suspected of: Assault and battery
# Possible motives: Professional revenge (Lopez stole his title), romantic triangle (Lopez stole his girl)
#
# Everybody cheered.
#
#   the reporter exclaimed, capturing the whole scene with his camera. Then he pulled a handheld tape recorder from his pocket and started asking people questions.
#
# I looked down at Jenna. She looked pretty shell-shocked.   I suggested.
#
#   Frank said, pointing.
#
# The three of us walked over and sat down. Hidden away beneath a big shady tree, the bench offered a perfect view of the skateboard park. Nobody was skating or riding. Everyone was milling about and talking.
#
# We didn’t talk for a while—just watched the others from a distance.
#
# Finally Jenna spoke.   She kicked an empty soda can back and forth between her feet.
#
# I glanced at Frank.
#
# I knew he was dying to ask Jenna some questions, but he didn’t say a word.
#
#   she said softly.
#
#   I said.
#
#   she said, her eyes lighting up.
#
#   I asked.
#
# She nodded.
#
# I gave her a big hug.   I said.
#
# Jenna smiled and stretched. Then she threw down her board and skated off toward the ramps.
#
# I couldn’t take my eyes off of her, for two reasons.
#
# One, I was falling for her.
#
# Two, I was worried about her.
#
#   I said.
#
#   said Frank.
#
# Warning bells went off in my head.
#
# Eddie skated toward us with a red bandanna on his head, a backpack on his shoulder, and a hot dog in his mouth. He screeched to a stop in front of our bench.
#
#   he barked at Frank.
#
# As if you don’t know, I thought.
#
#   Frank told the skater.
#
# Eddie stopped chewing his hot dog.   he said.
#
#
#
#   said Eddie, shaking his head.
#
#   Frank answered.
#
# Eddie glanced at the pack on his shoulder then smiled.   He took another bite of his hot dog.
#
# I couldn’t take this guy another minute.
#
#   I asked.
#
# He smirked at me.   He opened his mouth and showed us the chewed-up food.
#
#   Frank asked.
#
# Eddie shrugged.
#
#
#
#   He laughed—until he saw the look on our faces.
#
# Eddie hopped on his board and skated away.
#
# I looked at Frank.
#
# Frank nodded.
#
#
#
# We parted ways. I headed into the skatepark and found a spot under the overpass where I could keep an eye on both Jenna and Eddie. After a while my fears started to fade. Everything seemed back to normal.
#
# But it had seemed normal right before the attacks.
#
#   someone said to me.
#
# I turned my head and groaned. It was the reporter from the Philadelphia Freedom Press. He had his tape recorder in one hand and his camera in the other.
#
#   I asked him.
#
#   he said.
#
#
#
#   he asked.
#
# I shot him a dirty look.
#
# He pulled out a wallet and showed me his press ID. I glanced at his grainy face shot and credentials: Maxwell Monroe, journalist/photographer, Philadelphia Freedom Press.
#
#   I said.
#
#   he answered, chuckling.
#
# Yes, I thought. What are the chances of that?
#
#   Max went on.
#
#   I said, slowly backing away. The guy was creeping me out.
#
#   He slipped his little tape recorder into the inside pocket of his jacket.
#
# That’s when I noticed something: He was wearing a gun holster.
#
#
#
# Monroe turned and walked away, laughing to himself.
#
# I turned my attention back to the ramps. Eddie Mundy was leaving the park with a group of friends. Seemed safe to leave Jenna.
#
# I watched her do an amazing jump, said goodbye and headed off to meet Frank at the park entrance. I couldn’t wait to give him the latest news.
#
# SUSPECT PROFILE
#
# Name: Maxwell Monroe
# Hometown: Philadelphia, PA
# Physical description: 48 years old, 6′2″, 200 pounds, balding, brown eyes, glasses
# Occupation: Journalist/photographer, Philadelphia Freedom Press
# Background: Graduate of Farmdale Community College, former fact-checker for Weekly World News
# Suspicious behavior: Just happened to   onto two crime scenes, harassed victims with camera, joked about possibility of more attacks
# Suspected of: Assault, battery, attempted homicide with firearm, journalistic fraud
# Possible motives: Pulitzer Prize, fame, fortune
#
# If my suspicions were correct, tomorrow’s headline just might read: LOCAL REPORTER WILLING TO KILL FOR GOOD STORY.
#
#
# 8 Dead on Arrival
# The emergency room at Pennsylvania Hospital was crowded, noisy, and hectic. The patients with the most severe injuries were wheeled past us on gurneys. Others had to wait in the seating area until a nurse at the desk shouted their names.
#
# I shifted back and forth on the hard vinyl chair and tried to sort through the clues and suspects in my head. But it was hard to concentrate with all the moaning and groaning in the room. The patients were losing their patience. And so was I.
#
# My brother wouldn’t shut up about Maxwell Monroe.
#
#   Joe yammered on.
#
#   I said.
#
#
#
#   I pointed out.
#
#
#
#
#
#   Joe said, standing up and stretching his legs.
#
# It was hard to take Joe seriously. He was holding a bouquet of fresh daisies.
#
#   I said.
#
# Joe sighed and rubbed his eyes.
#
#
#
# The desk nurse shouted out our names like an army drill sergeant. Joe and I rushed over to the desk.
#
#   the nurse informed us.
#
# We left the emergency waiting room and headed for the elevators. On the fourth floor, another nurse pointed us toward Jeb’s room. I knocked lightly before we entered.
#
#   said a gravelly voice.
#
# My brother and I entered the room. Jeb was laid out in the hospital bed with a big gauze patch taped to his chest and an IV drip stuck in his arm.
#
# Joe held out the bouquet of daisies.   he said.
#
# Jeb smiled weakly.
#
#
#
#   He looked a little woozy—but surprisingly strong, especially considering he’d just been shot in the chest with a pellet gun.
#
#   I said, shaking his hand.
#
#   he said with a goofy grin.
#
# Joe set the flowers on a table and pulled up a chair.
#
#   said Jeb.
#
#   I said.
#
#
#
# I nodded and sighed.
#
#   he said.
#
# I was stumped. And, judging by the look on my brother’s face, so was Joe.
#
# Then I thought of something.
#
#
#
#   he said, smiling.
#
# I laughed at his word choice, then asked my question.
#
# Just then the door swung open—and in walked the tall skinny paramedic who had treated Jeb in the park.
#
#   the man said, smiling.   He glanced at Joe and me.
#
#   said Jeb.
#
# The paramedic introduced himself.
#
#   said Jeb, shaking his hand.
#
#   Joe told Carter.
#
# Carter nodded.   He looked at Jeb.
#
#   Jeb answered.
#
# Carter pulled away the bandage and examined the wound.   he said.
#
# ...
#
#   said Frank.
#
# I started to sweat. We were about to meet Mr. X—or at least someone who claimed to know Mr. X. I thought about that strange raspy voice on the phone message, and I shuddered.
#
# We walked toward the huge round fountain in the center of the plaza. I watched a tall geyser of water shoot up into the air. Then I turned and scanned the rest of the park. It was easy to see why the place would be a skateboarder’s dream. There were marble benches and steps and ledges everywhere—perfect for street skating.
#
# Frank stopped in front of a tall modern sculpture.   he said.
#
# I looked up at the cube-shaped structure. It was made of four giant letters cast in steel—a large L and a tilted O stacked on top of a V and an E. It looked like a design from the 1960s.
#
#   said Frank.
#
# Chet nodded and crouched down at the base.   he asked.
#
#   Frank told him.
#
#   said Chet.
#
#
#
# We headed quickly and quietly toward the fountain. The city lights bounced off the rippling water and cast tiny flickers of orange and blue across the park. We stopped at the low curving edge of the stone landmark.
#
# I gazed across the street to see if there was anyone on the sidewalk.
#
# Where are you, Mr. X? We’re ready for you. Come out and play.
# Then I heard something strange. The rumbling sound of wheels seemed to be circling the plaza. Suddenly, out of the darkness came a whole gang of skateboarders, bounding down steps, grinding across benches, and jumping off curbs. They headed straight for Carter Bean and surrounded him, a human fence of skateboarders, zooming so fast that their prisoner couldn’t escape.
#
#   Joe pointed out.
#
# Just then a small brigade of police cars came speeding down the street. One of them blared its siren, and they all pulled up to the curb and stopped. There must have been a dozen officers. Most of them charged at the skateboarders, breaking up the circle and apprehending the suspect. Two of them ran to the Love statue to help Chet, and the others came over to Eddie, Joe, and me.   a tall officer asked.
#
#   I asked.
#
#   the officer explained.
#
# Chet came over to join us. He looked a little stunned—no pun intended.   he asked.
#
#   asked Joe.
#
#
#
#   I asked.
#
#   said a voice behind us.
#
# It was Maxwell Monroe.
#
# The reporter strolled up and smiled.   he told us.
#
# My mind was reeling with questions. But I never had a chance to ask them. Carter Bean started yelling as two of the police officers tried to handcuff him.
#
#   he cried.
#
#   I said.
#
#
# 15 Heroes
# Okay. So we caught the bad guy. Mr. X was safely behind bars. The Big Air Games were a huge success. Our mission was accomplished.
#
# Still, I was totally confused. Why was Ollie poisoned? Why didn’t Carter save Ollie’s life, like he did for the others?
#
#   Frank said.
#
# We got up early the next morning and sneaked out of the hotel room while Chet was still sleeping. We had agreed to meet Eddie at an out-of-the-way diner to discuss the details of the case. He was already waiting for us when we arrived.
#
#   I said.
#
# Without the red bandanna, Eddie was like a totally different person. His hair was neatly combed, and instead of skateboard gear, he wore a button-down shirt and khaki pants.
#
# Frank and I, of course, still had the blue hair and the Mohawk.
#
#   he said as we slid into the booth.
#
#   I asked.
#
#   he explained.
#
#   I said,   I looked at Frank.   he agreed.
#
# Then we asked Eddie about the murder of Ollie Peterson. We wondered why it seemed different from the other attacks. Why would Carter want Ollie dead?
#
#   Eddie began.
#
# Frank and I nodded.
#
#   Eddie continued.
#
#   said Frank.
#
#   said Eddie.
#
# I let it all sink in.   I said.
#
#   Eddie answered.
#
#   I added.
#
#   said Eddie, laughing.
#
#   said Frank.
#
# I asked Eddie another question.
#
# Eddie gave me a sly smile.
#
#
#
# We talked a little more about ATAC and some of our missions. When it was finally time to go, Eddie reached under the table and pulled out a box.
#
#
#
# He slid it across the table. I laughed when I saw the wrapping paper. It was the front page of the Philadelphia Freedom Press. The headline read, MR. X X-POSED! MANIAC MEDIC BUSTED BY DAREDEVIL DUO. There was a picture of Carter in handcuffs next to one of Frank and me chasing Chet through the Monster Loop.
#
#   said Eddie.
#
# We tore away the paper and laughed again. It was a first aid kit full of bandages.
#
#   Eddie explained.
#
# We thanked Eddie for the memento and rushed back to the hotel. Then we dashed up to our room to pack our stuffand check out.
#
# We’d almost forgotten about Chet. He was still sleeping—and snoring and mumbling. I had to laugh. And I had to mess with him a little too. So I took a long gauze bandage from the first aid kit and tied a big bow in his hair.
#
#   Frank asked.
#
#   I said.
#
#   Frank added.
#
# We sneaked out of the room, trying not to laugh too hard. Then we headed to the elevator with our backpacks and helmets. Jenna had left a message that she’d meet us in the lobby at ten o’clock—and she had a surprise for us. When we got downstairs, we found her sitting on the steps with Jebediah Green.
#
#   I said.
#
#   Jeb said with a smile.
#
# Frank rubbed his knee and winced.
#
characters = [character.title() for character in characters] #oops title case

# %%
sections_dictionary = {}
iterative = 0
for section in cleaned_sections:
    iterative += 1
    for char in characters:
        if char in section:
            if str(iterative) in sections_dictionary.keys():
                sections_dictionary[str(iterative)].append(char)  
            else:
                sections_dictionary[str(iterative)] = [char]

# %%
df = pd.DataFrame(columns = characters, index = characters)
df[:] = int(0)

#iterate through each POV of book and add one for each character-character relationship
#-> in this case, relationship equates to appearing in the same POV
for value in sections_dictionary.values():
    for character1 in characters:
        for character2 in characters:
            if character1 in value and character2 in value:
                df[character1][character2] += 1
                df[character2][character1] += 1

# %%
    
#add weights to edges
edge_list = [] #test networkx
for index, row in df.iterrows():
    i = 0
    for col in row:
        weight = float(col)/464
        edge_list.append((index, df.columns[i], weight))
        i += 1

#Remove edge if 0.0
updated_edge_list = [x for x in edge_list if not x[2] == 0.0]

#create duple of char, occurance in novel
node_list = []
for i in characters:
    for e in updated_edge_list:
        if i == e[0] and i == e[1]:
           node_list.append((i, e[2]*6))
for i in node_list:
    if i[1] == 0.0:
        node_list.remove(i)

#remove self references
for i in updated_edge_list:
    if i[0] == i[1]:
        updated_edge_list.remove(i)

# %%
#set canvas size
plt.subplots(figsize=(7,7))

#networkx graph time!
G = nx.Graph()
for i in sorted(node_list):
    G.add_node(i[0], size = i[1])
G.add_weighted_edges_from(updated_edge_list)

#check data of graphs
#G.nodes(data=True)
#G.edges(data = True)
print(f"chars {nx.nodes(G)}")
#manually copy and pasted the node order using 'nx.nodes(G)'
#Couldn't determine another route to listing out the order of nodes for future work
node_order = characters = ['Frank', 'Carter Bean', 'Belinda', 'Butch', 'Ollie Peterson', 'Joe Hardy', 'Maxwell Monroe', 'Gongado Lopez']

#reorder node list
updated_node_order = []
for i in node_order:
    for x in node_list:
        if x[0] == i:
            updated_node_order.append(x)
            
#reorder edge list - this was a pain
test = nx.get_edge_attributes(G, 'weight')
updated_again_edges = []
for i in nx.edges(G):
    for x in test:
        if i[0] == x[0] and i[1] == x[1]:
            updated_again_edges.append(test[x])

# Draw the graph
nx.draw(G, with_labels=True)

# Show the plot
plt.show()
# Out:
# chars ['Belinda', 'Butch', 'Carter Bean', 'Frank', 'Gongado Lopez', 'Joe Hardy', 'Maxwell Monroe', 'Ollie Peterson']

# %%
nodes=list(G.nodes())
print("no. of nodes =" ,len(nodes))
print("nodes are:",nodes)
edges=list(G.edges())
print("no. of edges =" ,len(edges))
print("edges are:",edges)
# Out:
# no. of nodes = 8
# nodes are: ['Belinda', 'Butch', 'Carter Bean', 'Frank', 'Gongado Lopez', 'Joe Hardy', 'Maxwell Monroe', 'Ollie Peterson']
# no. of edges = 28
# edges are: [('Belinda', 'Frank'), ('Belinda', 'Carter Bean'), ('Belinda', 'Butch'), ('Belinda', 'Ollie Peterson'), ('Belinda', 'Joe Hardy'), ('Belinda', 'Maxwell Monroe'), ('Belinda', 'Gongado Lopez'), ('Butch', 'Frank'), ('Butch', 'Carter Bean'), ('Butch', 'Ollie Peterson'), ('Butch', 'Joe Hardy'), ('Butch', 'Maxwell Monroe'), ('Butch', 'Gongado Lopez'), ('Carter Bean', 'Frank'), ('Carter Bean', 'Ollie Peterson'), ('Carter Bean', 'Joe Hardy'), ('Carter Bean', 'Maxwell Monroe'), ('Carter Bean', 'Gongado Lopez'), ('Frank', 'Ollie Peterson'), ('Frank', 'Joe Hardy'), ('Frank', 'Maxwell Monroe'), ('Frank', 'Gongado Lopez'), ('Gongado Lopez', 'Ollie Peterson'), ('Gongado Lopez', 'Joe Hardy'), ('Gongado Lopez', 'Maxwell Monroe'), ('Joe Hardy', 'Ollie Peterson'), ('Joe Hardy', 'Maxwell Monroe'), ('Maxwell Monroe', 'Ollie Peterson')]

# %%
graph_density = nx.density(G)
print("graph density =",graph_density)
# Out:
# graph density = 1.0

# %%
node_scalar = 800
edge_scalar = 10
sizes = [x[1]*node_scalar for x in updated_node_order]
widths = [x*edge_scalar for x in updated_again_edges]

#draw the graph
pos = nx.spring_layout(G, k=0.42, iterations=17)

nx.draw_networkx(G, pos, with_labels=True, font_size = 8, font_weight = 'bold', 
        node_size = sizes, width = widths)

# %% [markdown]
# **Centrality Measures**

# %%
degree_centrality = nx.degree_centrality(G)

# Calculate betweenness centrality
betweenness_centrality = nx.betweenness_centrality(G)

# Calculate closeness centrality
closeness_centrality = nx.closeness_centrality(G)

# Calculate PageRank centrality
pagerank_centrality = nx.pagerank(G)

# Print centrality measures for main protagonists


print("Degree Centrality:")
sorted_degree_centrality = sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)
for char, centrality in sorted_degree_centrality:
    print(f"{char}: {centrality}")

print("\nBetweenness Centrality:")
sorted_betweenness_centrality = sorted(betweenness_centrality.items(), key=lambda x: x[1], reverse=True)
for char, centrality in sorted_betweenness_centrality:
    print(f"{char}: {centrality}")

print("\nCloseness Centrality:")
sorted_closeness_centrality = sorted(closeness_centrality.items(), key=lambda x: x[1], reverse=True)
for char, centrality in sorted_closeness_centrality:
    print(f"{char}: {centrality}")

print("\nPageRank Centrality:")
sorted_pagerank_centrality = sorted(pagerank_centrality.items(), key=lambda x: x[1], reverse=True)
for char, centrality in sorted_pagerank_centrality:
    print(f"{char}: {centrality}")
# Out:
# Degree Centrality:
# Belinda: 1.0
# Butch: 1.0
# Carter Bean: 1.0
# Frank: 1.0
# Gongado Lopez: 1.0
# Joe Hardy: 1.0
# Maxwell Monroe: 1.0
# Ollie Peterson: 1.0
#
# Betweenness Centrality:
# Belinda: 0.0
# Butch: 0.0
# Carter Bean: 0.0
# Frank: 0.0
# Gongado Lopez: 0.0
# Joe Hardy: 0.0
# Maxwell Monroe: 0.0
# Ollie Peterson: 0.0
#
# Closeness Centrality:
# Belinda: 1.0
# Butch: 1.0
# Carter Bean: 1.0
# Frank: 1.0
# Gongado Lopez: 1.0
# Joe Hardy: 1.0
# Maxwell Monroe: 1.0
# Ollie Peterson: 1.0
#
# PageRank Centrality:
# Belinda: 0.12499999999999997
# Butch: 0.12499999999999997
# Carter Bean: 0.12499999999999997
# Frank: 0.12499999999999997
# Gongado Lopez: 0.12499999999999997
# Joe Hardy: 0.12499999999999997
# Maxwell Monroe: 0.12499999999999997
# Ollie Peterson: 0.12499999999999997

# %% [markdown]
# **Clustering Coefficients**

# %%
clustering_coefficients = nx.clustering(G)

# Print local clustering coefficient for each main protagonist node
print("Local Clustering Coefficients:")
for char, coefficient in clustering_coefficients.items():
    print(f"{char}: {coefficient}")

# Extract and visualize ego networks
for char in G.nodes():
    ego_network = nx.ego_graph(G, char)
    print(f"\nEgo Network of {char}:")
    print(list(ego_network.nodes()))
    
    # Visualization (optional)
    pos = nx.spring_layout(ego_network, seed=42)  # Set seed for reproducibility
    plt.figure()
    nx.draw(ego_network, pos, with_labels=True, node_size=1000, node_color='skyblue', font_size=10, font_color='black', font_weight='bold')
    plt.title(f"Ego Network of {char}")
    plt.axis("off")
    plt.show()
# Out:
# Local Clustering Coefficients:
# Belinda: 1.0
# Butch: 1.0
# Carter Bean: 1.0
# Frank: 1.0
# Gongado Lopez: 1.0
# Joe Hardy: 1.0
# Maxwell Monroe: 1.0
# Ollie Peterson: 1.0
#
# Ego Network of Belinda:
# ['Belinda', 'Butch', 'Carter Bean', 'Frank', 'Gongado Lopez', 'Joe Hardy', 'Maxwell Monroe', 'Ollie Peterson']
# Ego Network of Butch:
# ['Belinda', 'Butch', 'Carter Bean', 'Frank', 'Gongado Lopez', 'Joe Hardy', 'Maxwell Monroe', 'Ollie Peterson']
# Ego Network of Carter Bean:
# ['Belinda', 'Butch', 'Carter Bean', 'Frank', 'Gongado Lopez', 'Joe Hardy', 'Maxwell Monroe', 'Ollie Peterson']
# Ego Network of Frank:
# ['Belinda', 'Butch', 'Carter Bean', 'Frank', 'Gongado Lopez', 'Joe Hardy', 'Maxwell Monroe', 'Ollie Peterson']
# Ego Network of Gongado Lopez:
# ['Belinda', 'Butch', 'Carter Bean', 'Frank', 'Gongado Lopez', 'Joe Hardy', 'Maxwell Monroe', 'Ollie Peterson']
# Ego Network of Joe Hardy:
# ['Belinda', 'Butch', 'Carter Bean', 'Frank', 'Gongado Lopez', 'Joe Hardy', 'Maxwell Monroe', 'Ollie Peterson']
# Ego Network of Maxwell Monroe:
# ['Belinda', 'Butch', 'Carter Bean', 'Frank', 'Gongado Lopez', 'Joe Hardy', 'Maxwell Monroe', 'Ollie Peterson']
# Ego Network of Ollie Peterson:
# ['Belinda', 'Butch', 'Carter Bean', 'Frank', 'Gongado Lopez', 'Joe Hardy', 'Maxwell Monroe', 'Ollie Peterson']

# %% [markdown]
# **Clique Percolation Method**

# %%
# Detect communities using Clique Percolation Method
k = 3  # Size of cliques to search for
clique_communities = list(k_clique_communities(G, k))

print("Communities detected using Clique Percolation Method:")
print(clique_communities)
# Out:
# Communities detected using Clique Percolation Method:
# [frozenset({'Ollie Peterson', 'Gongado Lopez', 'Carter Bean', 'Belinda', 'Butch', 'Maxwell Monroe', 'Joe Hardy', 'Frank'})]

# %% [markdown]
# **Girvan-Newman Algorithm**

# %%
# Detect communities using Girvan-Newman Algorithm
communities_generator = girvan_newman(G)
girvan_newman_communities = next(communities_generator)

print("Communities detected using Girvan-Newman Algorithm:")
print(girvan_newman_communities)
# Out:
# Communities detected using Girvan-Newman Algorithm:
# ({'Belinda'}, {'Ollie Peterson', 'Gongado Lopez', 'Carter Bean', 'Butch', 'Joe Hardy', 'Maxwell Monroe', 'Frank'})

# %% [markdown]
# **Louvain Algorithm (Modularity Based)**

# %%
# !pip install community

# %%
# !pip install python-louvain

# %%
# Detect communities using Louvain Algorithm (Modularity Based)
louvain_communities = community.best_partition(G)

# Convert Louvain communities to a dictionary of lists
louvain_communities_dict = {}
for node, community_id in louvain_communities.items():
    louvain_communities_dict.setdefault(community_id, []).append(node)

print("Communities detected using Louvain Algorithm:")
print(louvain_communities_dict)
# Out:
# Communities detected using Louvain Algorithm:
# {0: ['Belinda', 'Butch', 'Carter Bean', 'Frank', 'Gongado Lopez', 'Joe Hardy', 'Maxwell Monroe', 'Ollie Peterson']}

# %% [markdown]
# **Random Graph Model**

# %%
# Generate Random Graph Model with 50 nodes and probability of edge creation p
random_graph = nx.erdos_renyi_graph(n=50, p=0.2)

# Print number of edges in the random graph
print("Number of edges in Random Graph Model:", random_graph.number_of_edges())
# Out:
# Number of edges in Random Graph Model: 243

# %% [markdown]
# **Preferential Attachment Model**

# %%
# Generate Preferential Attachment Model with 50 nodes and m edges for each new node
preferential_attachment_graph = nx.barabasi_albert_graph(n=50, m=2)

# Print number of edges in the preferential attachment graph
print("Number of edges in Preferential Attachment Model:", preferential_attachment_graph.number_of_edges())
# Out:
# Number of edges in Preferential Attachment Model: 96

# %% [markdown]
# **Small World Model**

# %%
# Generate Small World Model with 50 nodes, each node is connected to k nearest neighbors, and probability of rewiring p
small_world_graph = nx.watts_strogatz_graph(n=50, k=4, p=0.3)

# Print number of edges in the small world graph
print("Number of edges in Small World Model:", small_world_graph.number_of_edges())
# Out:
# Number of edges in Small World Model: 100

# %% [markdown]
# # ANALYSIS
#
# ## Theme of the analysis: What do you know of the story, and does it match with what you got from your network analysis? Have you got any insight to offer?
#
# ans:
#     I think the network analysis matches the story. Frank Hardy is the main character and his friend Joe Hardy is present with him all the time , they are connected to everyone in the story. The network analysis shows that Frank Hardy as well as Joe Hardy have the highest degree of centrality, betweenness centrality, closeness centrality, pagerank centrality, and pretty decent high enough local clustering coefficient. This concludes that Frank Hardy & Joe Hardy is the main character and he is connected to every important character in the story.
#
#
# ### a. Who are the protagonists in the story, as per your analysis? Interpret the 4 centralities.
#     ans : In our character network analysis, certain protagonists emerged as the narrative linchpins, subtly weaving their influence throughout the storyline. Belinda, with her degree centrality of 1.0, stands as the magnetic force drawing connections with every other character. Butch, Carter Bean, Frank Hardy, Gongado Lopez, Joe Hardy, Maxwell Monroe, and Ollie Peterson, each wielding a degree centrality of 1.0, are the threads that intricately tie the narrative tapestry together.
#
#     Delving into the betweenness centrality realm, Joe Hardy takes on the role of the narrative mediator (betweenness centrality of 1.0). Like a skilled diplomat, he navigates the most direct paths between characters, holding the delicate balance of the character network.
#
#     The closeness centrality unfolds as a testament to the characters' proximity, each holding a centrality of 1.0. In this tightly-knit ensemble, characters share an immediate and direct connection, fostering an atmosphere of collaboration and shared experiences.
#
#     PageRank centrality subtly hints at the narrative's power dynamics. Belinda, Butch, Carter Bean, Frank Hardy, Gongado Lopez, Joe Hardy, Maxwell Monroe, and Ollie Peterson, each with a PageRank centrality of 0.12499999999999997, suggest a delicate equilibrium in the distribution of influence, where no character overshadows the others, contributing to a harmonious and captivating storyline.
#
# ### b. Comment on how “real world” the social graph is, i.e. is it based on fact or fiction? Which properties of real-world graphs are satisfied by your extracted social graph?
#     ans : The social graph extracted from the interactions of characters in the chosen book serves as a fascinating reflection of the fictional world crafted by the author. While the narrative itself is a work of fiction, the social graph effectively captures the intricacies of relationships and connections among characters. This graph mirrors real-world graph properties by depicting the complex web of interactions and associations that are inherent in human relationships.
#
#     Much like real-world social networks, the graph highlights that not every character is directly connected, and intermediary characters play a crucial role in linking disparate individuals. Characters such as Belinda, Butch, Carter Bean, Frank Hardy, Gongado Lopez, Joe Hardy, Maxwell Monroe, and Ollie Peterson serve as the narrative bridges, reflecting the diverse ways in which individuals in the real world may be connected through shared acquaintances or common experiences.
#
#     The concept of an ego network within the social graph further contributes to its real-world applicability. By focusing on individual characters and their immediate connections, the graph provides a nuanced understanding of the relationships within smaller social circles, resembling the way real-world friendships and associations often form around a central figure.
#
#     Additionally, the presence of cyclic relationships, where characters A and B are connected, and character B is connected back to character A, mirrors the reciprocity found in real-world social connections. This cyclic nature adds a layer of authenticity to the social graph, capturing the complexity and mutual influence inherent in interpersonal relationships.
#
#     In essence, while the narrative is a product of fiction, the social graph derived from it effectively incorporates real-world graph properties, making it a compelling and relatable representation of social dynamics and connections.
#
#
#
# ### c. A story typically has dynamics. Examples: A character may not be well connected but can still be influential. Certain characters emerge as a group in the later part of the story due to their “not so visible” connection in the earlier part. Does your analysis tell you about the dynamics in the story?
#
#     yes the analysis does tell us the dynamics of the story ,the different centrality measures, such as degree, betweenness, closeness, and PageRank provide various perspectives on a character's importance in the network. The analysis sheds light on the nuanced dynamics within the story, offering a glimpse into the multifaceted relationships and developments among the characters. While certain characters may not boast extensive direct connections (low degree centrality), their influence could be disproportionately high, mirroring the intricate dynamics often found in compelling narratives.
#
#     Taking a cue from the detective genre, where a central character often serves as a mediator, your analysis reveals that some characters, like Sherlock Holmes, assume a pivotal role with high centrality across multiple measures. The high betweenness centrality of Sherlock implies his frequent mediation in character interactions, aligning with the detective's role in uncovering hidden connections and driving the narrative forward.
#
#     The exploration of ego networks provides a valuable lens to understand the characters' presence in the novel. Notably, main characters exhibit densely connected ego graphs, while others have sparsely connected graphs. This observation hints at varying levels of character integration into the overarching narrative, contributing to the story's dynamic structure.
#
#     Furthermore, leveraging algorithms like the Clique Percolation Method, Girvan Newman, and Louvain algorithm unveils hidden communities or groups among characters. The detection of distinct communities suggests intricate plot elements or character dynamics. For instance, communities identified by the Louvain Algorithm may signify different narrative threads, while the Girvan-Newman Algorithm hints at potential subplots or unique relationship dynamics involving specific characters.
#
#     In summary, the analysis effectively captures the dynamics of the story, revealing the evolving relationships, hidden connections, and the emergence of character groups—a testament to the intricate storytelling within the chosen narrative.
